# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading data
data=pd.read_csv('ODI_Match_info.csv')
data
# Out:
#            id   season          city        date        team1        team2  \
# 0     1389389  2023/24        Indore  2023/09/24        India    Australia
# 1     1336129     2023    Nottingham  2023/09/23      England      Ireland
# 2     1395701     2023         Dhaka  2023/09/23  New Zealand   Bangladesh
# 3     1389388  2023/24    Chandigarh  2023/09/22    Australia        India
# 4     1395700     2023         Dhaka  2023/09/21  New Zealand   Bangladesh
# ...       ...      ...           ...         ...          ...          ...
# 2374    65634  2002/03        Sydney  2003/01/09    Sri Lanka    Australia
# 2375    64817  2002/03    Wellington  2003/01/08  New Zealand        India
# 2376    64816  2002/03    Queenstown  2003/01/04        India  New Zealand
# 2377    64815  2002/03  Christchurch  2003/01/01        India  New Zealand
# 2378    64814  2002/03        Napier  2002/12/29  New Zealand        India
#
# ...

# %%
#desribing the data 
data.describe().style
# Out:
# <style  type="text/css" >
# </style><table id="T_fbcea641_d65a_11ee_8944_605718b18860" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >dl_applied</th>        <th class="col_heading level0 col2" >win_by_runs</th>        <th class="col_heading level0 col3" >win_by_wickets</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fbcea641_d65a_11ee_8944_605718b18860level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_fbcea641_d65a_11ee_8944_605718b18860row0_col0" class="data row0 col0" >2379.000000</td>
#                         <td id="T_fbcea641_d65a_11ee_8944_605718b18860row0_col1" class="data row0 col1" >2379.000000</td>
#                         <td id="T_fbcea641_d65a_11ee_8944_605718b18860row0_col2" class="data row0 col2" >2379.000000</td>
# ...

# %% [markdown]
# # Winner Frequency

# %%
# winning proportionality of countires 
data1 = data['winner'].value_counts()
plt.figure(figsize=(10,4))
sns.barplot(x=data1.index, y=data1.values)
plt.title('Winner Frequency',size=30)
plt.xlabel('Winners')
plt.xticks(rotation=90)
plt.ylabel('Frequency')
plt.savefig("figure.png")

# %% [markdown]
# # Number of Matches per Season

# %%
# number of matches played in different seasons
data2 = data['season'].value_counts().sort_index()
plt.figure(figsize=(12,6))
sns.lineplot(x=data2.index, y=data2.values)
plt.title('Number of Matches Per Season',size=30)
plt.xlabel('Season')
plt.ylabel('Matches Played')
plt.xticks(rotation=90)
plt.savefig("figure1.png")

# %% [markdown]
# #  correlation

# %%
#Calculate the correlation matrix
data3 = data.corr()
# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(10,6))
sns.heatmap(data3, annot=True, cmap='icefire')
plt.title('Correlation Heatmap')
plt.savefig("figure2.png")
